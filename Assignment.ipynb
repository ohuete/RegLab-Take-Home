# %%
import numpy as np
import pandas as pd
from pathlib import Path
from collections import Counter

# %%
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced

# %%
# Create file path for datasets
file_path_fv = "./resources/food_violations_seattle.csv"

# Read csv as dataframe
fv_df = pd.read_csv(file_path_fv)

# view df
fv_df.head(5)
# Out:
#    Unnamed: 0 inspection_id           restaurant_id  \
# 0           0     DA2383404  ZriNDCVxkCdVEO-X2sjHFw
# 1           1     DA2304227  ZriNDCVxkCdVEO-X2sjHFw
# 2           2     DA2278690  ZriNDCVxkCdVEO-X2sjHFw
# 3           3     DA2183562  ZriNDCVxkCdVEO-X2sjHFw
# 4           4     DA2142912  ZriNDCVxkCdVEO-X2sjHFw
#
#   inspection_period_start_date inspection_period_end_date  \
# 0          2012-02-06 00:00:00        2012-10-02 00:00:00
# 1          2011-11-03 00:00:00        2012-02-06 00:00:00
# 2          2011-01-06 00:00:00        2011-11-03 00:00:00
# 3          2010-08-26 00:00:00        2011-01-06 00:00:00
# 4          2010-02-25 00:00:00        2010-08-26 00:00:00
#
#    inspection_penalty_score  inspection_average_prev_penalty_scores  \
# 0                        46                                    54.0
# 1                        82                                    86.0
# 2                        24                                    67.0
# 3                        71                                    89.0
# 4                        64                                    69.0
#
#    inspection_prev_penalty_score                     cuisines  zip_code  \
# 0                             50  ['Japanese', 'Restaurants']     98116
# 1                             76  ['Japanese', 'Restaurants']     98116
# 2                             41  ['Japanese', 'Restaurants']     98116
# 3                             28  ['Japanese', 'Restaurants']     98116
# 4                             60  ['Japanese', 'Restaurants']     98116
#
#    review_count  non_positive_review_count  average_review_rating  \
# 0             1                          0               5.000000
# 1             3                          0               4.000000
# 2             7                          0               4.428571
# 3             3                          1               3.333333
# 4             4                          2               3.250000
#
#                                      review_contents
# 0  We went here this past weekend with zero expec...
# 1  Lots of young families . Kind of sparse &#160;...
# 2  This place is a gem! My husband and I didn't h...
# 3  Honestly, my expectations were not that high. ...
# 4  Yep, like it says.My friend and I were on the ...

# %%
# Create file path for datasets
file_path_cuisine = "./resources/cuisines.csv"

# Read csv as dataframe
cuisine_df = pd.read_csv(file_path_cuisine)

# view df
cuisine_df.head(5)
# Out:
#              x  asian  ethnic
# 0     Japanese      1       1
# 1  Restaurants      0       0
# 2   Sandwiches      0       0
# 3   Vietnamese      1       1
# 4        Delis      0       0

# %%
# filter cuisines to display only asian + ethnicity variables 
new_cuisine_df = cuisine_df.query('asian == 1 or ethnic == 1')

# %%
# rename columns to match with main dataset
new_cuisine_df.rename(columns={'x': 'cuisines'}, inplace=True)
new_cuisine_df.head()
# Out:
# /var/folders/b8/nrfjwjrd6lxbbzr7h9h1xzv40000gn/T/ipykernel_60615/2047341941.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_cuisine_df.rename(columns={'x': 'cuisines'}, inplace=True)
#      cuisines  asian  ethnic
# 0    Japanese      1       1
# 3  Vietnamese      1       1
# 5     Dim Sum      1       1
# 7   Cantonese      1       1
# 8     Chinese      1       1

# %%
# filter by inspection_penalty_score of 10 or more
new_fv_df = fv_df.query('inspection_penalty_score >= 10')
new_fv_df.head(25)
# Out:
#     Unnamed: 0 inspection_id           restaurant_id  \
# 0            0     DA2383404  ZriNDCVxkCdVEO-X2sjHFw
# 1            1     DA2304227  ZriNDCVxkCdVEO-X2sjHFw
# 2            2     DA2278690  ZriNDCVxkCdVEO-X2sjHFw
# 3            3     DA2183562  ZriNDCVxkCdVEO-X2sjHFw
# 4            4     DA2142912  ZriNDCVxkCdVEO-X2sjHFw
# 5            5     DA2081169  ZriNDCVxkCdVEO-X2sjHFw
# 6            6     DA2070387  ZriNDCVxkCdVEO-X2sjHFw
# 7            7     DA1961408  ZriNDCVxkCdVEO-X2sjHFw
# 8            8     DA1892158  ZriNDCVxkCdVEO-X2sjHFw
# 15          15     DA2411831  jJp7BaSZ4eu0MfqkZjuJGw
# 16          16     DA2363683  jJp7BaSZ4eu0MfqkZjuJGw
# 17          17     DA2331377  jJp7BaSZ4eu0MfqkZjuJGw
# 18          18     DA2411832  jJp7BaSZ4eu0MfqkZjuJGw
# 19          19     DA2363684  jJp7BaSZ4eu0MfqkZjuJGw
# 20          20     DA2331378  jJp7BaSZ4eu0MfqkZjuJGw
# 21          21     DA2351885  jJp7BaSZ4eu0MfqkZjuJGw
# 22          22     DA2384534  jJp7BaSZ4eu0MfqkZjuJGw
# 23          23     DA2316516  jJp7BaSZ4eu0MfqkZjuJGw
# 28          28     DA2161059  hWl2YZZhwJIZvbnncHecJg
# 30          30     DA1961359  hWl2YZZhwJIZvbnncHecJg
# 34          34     DA2400229  u4lNLYSrMWGJhFLoKwsBzw
# 35          35     DA2317508  u4lNLYSrMWGJhFLoKwsBzw
# 36          36     DA2291979  u4lNLYSrMWGJhFLoKwsBzw
# 37          37     DA2274987  u4lNLYSrMWGJhFLoKwsBzw
# 38          38     DA2266810  u4lNLYSrMWGJhFLoKwsBzw
#
#    inspection_period_start_date inspection_period_end_date  \
# 0           2012-02-06 00:00:00        2012-10-02 00:00:00
# 1           2011-11-03 00:00:00        2012-02-06 00:00:00
# 2           2011-01-06 00:00:00        2011-11-03 00:00:00
# 3           2010-08-26 00:00:00        2011-01-06 00:00:00
# 4           2010-02-25 00:00:00        2010-08-26 00:00:00
# 5           2009-12-04 00:00:00        2010-02-25 00:00:00
# 6           2009-03-17 00:00:00        2009-12-04 00:00:00
# 7           2008-09-04 00:00:00        2009-03-17 00:00:00
# 8           2008-02-04 00:00:00        2008-09-04 00:00:00
# 15          2012-08-21 00:00:00        2013-02-05 00:00:00
# 16          2012-05-07 00:00:00        2012-07-09 00:00:00
# 17          2011-11-04 00:00:00        2012-05-07 00:00:00
# 18          2012-08-21 00:00:00        2013-02-05 00:00:00
# 19          2012-05-07 00:00:00        2012-07-09 00:00:00
# 20          2011-11-04 00:00:00        2012-05-07 00:00:00
# 21          2011-05-06 00:00:00        2012-07-16 00:00:00
# 22          2012-03-20 00:00:00        2012-10-29 00:00:00
# 23          2011-10-06 00:00:00        2012-03-20 00:00:00
# 28          2009-10-26 00:00:00        2010-10-23 00:00:00
# 30          2008-03-28 00:00:00        2009-03-12 00:00:00
# 34          2012-03-22 00:00:00        2012-12-22 00:00:00
# 35          2011-12-23 00:00:00        2012-03-22 00:00:00
# 36          2011-10-26 00:00:00        2011-12-23 00:00:00
# 37          2011-09-29 00:00:00        2011-10-26 00:00:00
# 38          2011-04-07 00:00:00        2011-09-29 00:00:00
#
#     inspection_penalty_score  inspection_average_prev_penalty_scores  \
# 0                         46                                    54.0
# 1                         82                                    86.0
# 2                         24                                    67.0
# 3                         71                                    89.0
# 4                         64                                    69.0
# 5                         53                                    69.0
# 6                         43                                    47.0
# 7                         83                                    94.0
# 8                         63                                    65.0
# 15                        42                                    51.0
# 16                        48                                    19.0
# 17                        46                                    91.0
# 18                        64                                    75.0
# 19                        88                                    72.0
# 20                        91                                    71.0
# 21                        44                                    78.0
# 22                        82                                    52.0
# 23                        79                                    65.0
# 28                        10                                     8.0
# 30                        40                                     0.0
# 34                        38                                    34.0
# 35                        71                                    95.0
# 36                        72                                    55.0
# 37                        35                                    64.0
# 38                        43                                    41.0
#
#     inspection_prev_penalty_score  \
# 0                              50
# 1                              76
# 2                              41
# 3                              28
# 4                              60
# 5                              50
# 6                              33
# 7                              58
# 8                              45
# 15                             45
# 16                             53
# 17                             53
# 18                             62
# 19                            118
# 20                             55
# 21                             64
# 22                             53
# 23                             38
# 28                              0
# 30                              0
# 34                             75
# 35                             42
# 36                             52
# 37                             43
# 38                             51
#
#                                              cuisines  zip_code  review_count  \
# 0                         ['Japanese', 'Restaurants']     98116             1
# 1                         ['Japanese', 'Restaurants']     98116             3
# 2                         ['Japanese', 'Restaurants']     98116             7
# 3                         ['Japanese', 'Restaurants']     98116             3
# 4                         ['Japanese', 'Restaurants']     98116             4
# 5                         ['Japanese', 'Restaurants']     98116             1
# 6                         ['Japanese', 'Restaurants']     98116             1
# 7                         ['Japanese', 'Restaurants']     98116             2
# 8                         ['Japanese', 'Restaurants']     98116             1
# 15                      ['Vietnamese', 'Restaurants']     98106             3
# 16                      ['Vietnamese', 'Restaurants']     98106             1
# 17                      ['Vietnamese', 'Restaurants']     98106             2
# 18                      ['Vietnamese', 'Restaurants']     98106             3
# 19                      ['Vietnamese', 'Restaurants']     98106             1
# 20                      ['Vietnamese', 'Restaurants']     98106             2
# 21                      ['Vietnamese', 'Restaurants']     98106             3
# 22                      ['Vietnamese', 'Restaurants']     98106             2
# 23                      ['Vietnamese', 'Restaurants']     98106             2
# 28                           ['Delis', 'Restaurants']     98103            21
# 30                           ['Delis', 'Restaurants']     98103            23
# 34  ['Dim Sum', 'Seafood', 'Cantonese', 'Chinese',...     98118            10
# 35  ['Dim Sum', 'Seafood', 'Cantonese', 'Chinese',...     98118             7
# 36  ['Dim Sum', 'Seafood', 'Cantonese', 'Chinese',...     98118             3
# 37  ['Dim Sum', 'Seafood', 'Cantonese', 'Chinese',...     98118             1
# 38  ['Dim Sum', 'Seafood', 'Cantonese', 'Chinese',...     98118            11
#
#     non_positive_review_count  average_review_rating  \
# 0                           0               5.000000
# 1                           0               4.000000
# 2                           0               4.428571
# 3                           1               3.333333
# 4                           2               3.250000
# 5                           1               2.000000
# 6                           1               3.000000
# 7                           0               4.000000
# 8                           1               3.000000
# 15                          2               3.000000
# 16                          1               3.000000
# 17                          0               4.500000
# 18                          2               3.000000
# 19                          1               3.000000
# 20                          0               4.500000
# 21                          1               4.000000
# 22                          1               4.000000
# 23                          0               4.500000
# 28                          3               4.238095
# 30                          4               3.791667
# 34                          4               3.545455
# 35                          3               3.571429
# 36                          3               2.000000
# 37                          0               4.000000
# 38                          1               4.250000
#
#                                       review_contents
# 0   We went here this past weekend with zero expec...
# 1   Lots of young families . Kind of sparse &#160;...
# 2   This place is a gem! My husband and I didn't h...
# 3   Honestly, my expectations were not that high. ...
# 4   Yep, like it says.My friend and I were on the ...
# 5   i recently ate here....next time you'll have t...
# 6   After my first 3 visits I boldly proclaimed th...
# 7   The best teriyaki I have had in Seattle!!! &#1...
# 8   Clean joint, good selection of food, friendly ...
# 15  I have been here twice, service is good, perso...
# 16  Mehhhhh.I think I'm being extremely generous w...
# 17  Here's a sentence you will never hear Rick San...
# 18  I have been here twice, service is good, perso...
# 19  Mehhhhh.I think I'm being extremely generous w...
# 20  Here's a sentence you will never hear Rick San...
# 21  Mehhhhh.I think I'm being extremely generous w...
# 22  Mehhhhh.I think I'm being extremely generous w...
# 23  Here's a sentence you will never hear Rick San...
# 28  I've been slowly taking time and actually doin...
# 30  As a former morning coffee drinker, there's so...
# 34  I have not been here for many years since they...
# 35  Yaaahhhh, I am happy someone moved into this v...
# 36  Because I like to try different restaurants, I...
# 37  We go out for dim sum probably once a month. &...
# 38  This was only based off one visit &#160;for di...

# %%
# merge data frames from cuisines column to include only 1 values

# %%
# keep important columns such as inspection penalty scores and cuisne

# %%
# Generate a logistical regression
